# %%
#Evaluation function, plot function, MA functions
import numpy as np
import pandas as pd
from datetime import datetime
from matplotlib import pyplot as plt

DATA_PATH = "BTC-Daily.csv"

def import_data(path):
    """
    Imports Bitcoin price data
    Returns: a 2d numpy array with unix timestamp and opening prices as the rows
    """
    df = pd.read_csv(path)
    arr = df[["unix", "close"]].to_numpy().T # Transpose so timestamp and price are rows
    arr = arr[:, arr[0,:].argsort()]         # Sort in ascending order of the first row (timestamp)
    return arr

def training_testing_split(data, unix_cutoff):
    training = data[:, data[0] < unix_cutoff]
    testing = data[:, data[0] >= unix_cutoff]
    return training, testing

def pad(price, days):
    """ Pads the price array as done in the task sheet """
    padding = -np.flip(price[1:days])
    return np.append(padding, price)

def WMA(price, days, kernel):
    price = pad(price, days)
    wma = np.correlate(price, kernel, mode="valid")
    return wma

def SMA(price, days):
    """Simple moving average"""
    K = 1/days * np.ones(days)
    return WMA(price, days, K)

def LMA(price, days):
    """Linear moving average"""
    K = 2 * np.linspace(0, 1/days, days)
    return WMA(price, days, K)

def EMA(price, days, alpha):
    """Exponential moving average"""
    K = alpha * np.power(1 - alpha, np.linspace(0, days, days)[::-1])
    K/= sum(K)
    return WMA(price, days, K)

def combined_WMA(price, sma_weight, sma_length, lma_weight, lma_length, ema_weight, ema_length, ema_alpha):
    sma = SMA(price, int(sma_length))
    lma = LMA(price, int(lma_length))
    ema = EMA(price, int(ema_length), ema_alpha)
    return (sma_weight * sma + lma_weight * lma + ema_weight * ema) / (sma_weight + lma_weight + ema_weight)

def generate_ma_crossover_signals(short_ma, long_ma):
    """
    Generate moving average crossover signals

    This function creates trading signals based on crossover of short and long-term
    moving averages.

    Args:
        short_ma: array containing the more reactive weighted moving averages
        long_ma: aeeay containing the less reactive weighted moving averages

    Returns:
        Tuple containing:
        - numpy array of signals: +1 (buy), -1 (sell), 0 (hold)
        - short moving average values
        - long moving average values
    """

    # Ensure arrays have the same length
    # This is important because different MA types/windows can produce arrays of different lengths
    if len(short_ma) != len(long_ma):
        print("WARNING: Moving averages are of different lengths")
        min_len = min(len(short_ma), len(long_ma))
        short_ma = short_ma[-min_len:]
        long_ma = long_ma[-min_len:]

    # Generate signals based on crossovers
    # Signal convention: +1 (buy), -1 (sell), 0 (hold)
    # This matches the expected format in the backtesting module
    crossover_signals = np.zeros(len(short_ma), dtype=int)
    diff = short_ma - long_ma

    for i in range(1, len(short_ma)):

        # Buy signal: short MA crosses above long MA
        if diff[i] > 0 and diff[i-1] <= 0:
            crossover_signals[i] = 1
        # Sell signal: short MA crosses below long MA
        elif diff[i] < 0 and diff[i-1] >= 0:
            crossover_signals[i] = -1

    return crossover_signals

def evaluate(parameters, prices, start_amount=1000, fee_rate=0.03, verbose=False, plot=False):
    """
    Evaluation function with all backtesting rules implemented inside.

    Parameters:
    - parameters: np.ndarray of strategy parameters (length = 14 for 2 WMA with 7 weights each)
    - prices: np.ndarray of historical prices
    - start_amount: starting USD capital
    - fee_rate: transaction fee (default 3%)

    Returns:
    - Final portfolio value in USD
    """

    # Split parameters between both wma
    short_params = parameters[:7]
    long_params = parameters[7:]

    # Calculate moving averages
    short_wma = combined_WMA(prices, *short_params)
    long_wma = combined_WMA(prices, *long_params)

    # Generate buy signal
    buy_signal = generate_ma_crossover_signals(short_wma, long_wma)

    # Simulate trading logic according to evaluation spec
    cash = start_amount
    btc = 0.0

    for i, signal in enumerate(buy_signal):
        current_price = prices[i]
        if signal == 1 and cash > 0: # Buy signal
            btc = cash / current_price * (1 - fee_rate)
            if verbose: print(f"Buying {btc:.2f}BTC with {cash:.2f}USD at time {i}")
            cash = 0.0
        elif signal == -1 and btc > 0:
            cash = btc * current_price * (1 - fee_rate)
            if verbose: print(f"Selling {btc:.2f}BTC into {cash:.2f}USD at time {i}")
            btc = 0.0

    # Final sell if BTC remaining
    if btc > 0:
        cash = btc * prices[-1] * (1 - fee_rate)

    if plot: plot_ma_signals(prices, short_wma, long_wma, buy_signal)

    return cash

def plot_ma_signals(prices, short_wma, long_wma, buy_signal, save_fig=False, fig_path=None):
    """
    Plot moving average signals

    Args:
        prices: Array of price data
        short_wma: Length of short moving average window
        long_wma: Length of long moving average window
        save_fig: Whether to save the figure
        fig_path: Path to save the figure
    """
    # Create figure
    plt.figure(figsize=(12, 8))

    # Plot price and moving averages
    plt.plot(prices, label='Price', alpha=0.5, linewidth=1)
    plt.plot(short_wma, label=f'Short WMA', linewidth=1.5)
    plt.plot(long_wma, label=f'Long WMA', linewidth=1.5)

    # Plot buy signals
    buy_indices = np.where(buy_signal == 1)[0]
    sell_indices = np.where(buy_signal == -1)[0]

    plt.plot(buy_indices, prices[buy_indices], '^', markersize=10, color='g', label='Buy Signal')
    plt.plot(sell_indices, prices[sell_indices], 'v', markersize=10, color='r', label='Sell Signal')

    plt.title('Moving Average Crossover Strategy')
    plt.xlabel('Time')
    plt.ylabel('Price')
    plt.legend()
    plt.grid(True)

    if save_fig and fig_path:
        import os
        os.makedirs(os.path.dirname(fig_path), exist_ok=True)
        plt.savefig(fig_path)
        plt.close()
    else:
        plt.show()

PARAM_NAMES = ["Short SMA weight", "Short SMA length", "Short LMA weight", "Short LMA length", "Short EMA weight", "Short EMA length", "Short EMA alpha",
                "Long SMA weight", "Long SMA length", "Long LMA weight", "Long LMA length", "Long EMA weight", "Long EMA length", "Long EMA alpha"]

def print_parameters(parameters):
    for name, parameter in zip(PARAM_NAMES, parameters):
        if "length" in name:
            print(f"{name}: {int(parameter)}")
        else:
            print(f"{name}: {round(parameter, 6)}")

# %%
#PSO Implementation
import numpy as np

class ParticleSwarmOptimizer:
  # Constructor:
    def __init__(self, fitness_function, bounds, num_particles=30, max_iter=50, w=0.5, c1=1.5, c2=1.5):
        self.fitness = fitness_function
        self.bounds = np.array(bounds)  # shape (n_dimensions)
        self.num_particles = num_particles
        self.max_iter = max_iter
        self.dim = self.bounds.shape[0]
        self.w, self.c1, self.c2 = w, c1, c2

        # Initializing the swarm:
        self.swarm = []
        for _ in range(num_particles):
            position = np.random.uniform(self.bounds[:, 0], self.bounds[:, 1]) # Random initial position
            velocity = np.zeros(self.dim)
            particle = {
                'position': position,
                'velocity': velocity,
                'best_pos': position.copy(),
                'best_score': -np.inf
            }
            self.swarm.append(particle)

        self.global_best_pos = None
        self.global_best_score = -np.inf

  # Components:
  # fitness_function: The function to optimize (maximize).
  # bounds: List/array of shape (n_dimensions, 2), giving the lower and upper bounds for each dimension.
  # num_particles: Number of candidate solutions (particles).
  # max_iter: Number of iterations.
  # w: Inertia weight, controls how much of the previous velocity is retained.
  # c1, c2: Acceleration coefficients (cognitive and social).


  # Main function:
    def optimize(self):
        for _ in range(self.max_iter):
          # Evaluating each particle for max_iter number of times
            for particle in self.swarm:
                pos = particle['position']
                score = self.fitness(pos)

                if score > particle['best_score']: # If the score is better than the particle’s previous best, we update it
                    particle['best_score'] = score
                    particle['best_pos'] = pos.copy()

                if score > self.global_best_score: # If the score is better than the global best, we update it
                    self.global_best_score = score
                    self.global_best_pos = pos.copy()

            # Updating the Velocities and Positions
            for particle in self.swarm:
                r1, r2 = np.random.rand(self.dim), np.random.rand(self.dim) # Generates two vectors of random values between 0 and 1 for each dimension. These are used in the velocity update rule
                cognitive = self.c1 * r1 * (particle['best_pos'] - particle['position'])
                social = self.c2 * r2 * (self.global_best_pos - particle['position'])
                particle['velocity'] = self.w * particle['velocity'] + cognitive + social
                particle['position'] += particle['velocity']
                particle['position'] = np.clip(particle['position'], self.bounds[:, 0], self.bounds[:, 1]) # Restricts each particle’s new position so that it stays within the defined bounds after velocity updates.

        return self.global_best_pos, self.global_best_score

# %%
# HCA Implementation

class HCA:
    def __init__(self, objective_func, bounds, step_size=0.1, n_iterations=1000):
        """
        Hill Climbing Algorithm implementation

        Parameters:
        - objective_func: Objective function to optimize
        - bounds: Parameter bounds [(min, max), ...]
        - step_size: Size of step for parameter updates
        - n_iterations: Number of iterations
        """
        self.objective_func = objective_func
        self.bounds = bounds
        self.step_size = step_size
        self.n_iterations = n_iterations
        self.dim = len(bounds)

        # Initialize current position
        self.current_position = np.random.uniform(
            [b[0] for b in bounds],
            [b[1] for b in bounds]
        )

        # Initialize current fitness
        self.current_fitness = self.objective_func(self.current_position)

    def generate_neighbor(self, position):
        """Generate a neighboring solution"""
        neighbor = position.copy()

        # Randomly select a dimension to modify
        dim = np.random.randint(self.dim)

        # Generate a random step
        step = np.random.uniform(-self.step_size, self.step_size)

        # Update the selected dimension
        neighbor[dim] += step

        # Ensure the new value is within bounds
        neighbor[dim] = np.clip(neighbor[dim], self.bounds[dim][0], self.bounds[dim][1])

        return neighbor

    def optimize(self):
        """Execute optimization"""
        best_position = self.current_position.copy()
        best_fitness = self.current_fitness

        for iteration in range(self.n_iterations):
            # Generate a neighbor
            neighbor = self.generate_neighbor(self.current_position)

            # Evaluate the neighbor
            neighbor_fitness = self.objective_func(neighbor)

            # If the neighbor is better, move to it
            if neighbor_fitness > self.current_fitness:
                self.current_position = neighbor
                self.current_fitness = neighbor_fitness

                # Update best solution if necessary
                if neighbor_fitness > best_fitness:
                    best_position = neighbor.copy()
                    best_fitness = neighbor_fitness

            print(
                f"Iteration {iteration + 1}/{self.n_iterations}, Current fitness: {self.current_fitness:.2f}, Best fitness: {best_fitness:.2f}")

        return best_position, best_fitness

# %%
# PSO Invoke

data = import_data(DATA_PATH)
training_data, testing_data = training_testing_split(data, datetime(2020, 1, 1).timestamp())

prices = training_data[1]

#EUSHA
# Defining the bounds for the parameters (14 total)
bounds = [
    [0, 1],    # short_wma_weight_1
    [1, 500], # short_wma_length_1
    [0, 1],    # short_wma_weight_2
    [1, 500], # short_wma_length_2
    [0, 1],    # short_wma_weight_3
    [1, 500], # short_wma_length_3
    [0.01, 1],    # short_wma_alpha for EMA
    [0, 1],    # long_wma_weight_1
    [1, 500], # long_wma_length_1
    [0, 1],    # long_wma_weight_2
    [1, 500], # long_wma_length_2
    [0, 1],    # long_wma_weight_3
    [1, 500], # long_wma_length_3
    [0.01, 1]     # long_wma_alpha for EMA (second one)
]

# Wrapping the evaluate function to accept only weights
def fitness_function(weights):
    return evaluate(weights, prices)

# Initialize and run PSO
pso = ParticleSwarmOptimizer(
    fitness_function=fitness_function,
    bounds=bounds,
    num_particles=100,
    max_iter=100
)

best_params, best_score = pso.optimize()

print("Best Score: ", best_score)
print("Best Parameters: ")
print_parameters(best_params)

# Evaluate best parameters on test set
test_fitness = evaluate(best_params, testing_data[1], plot=True)
print(f"Test set fitness: {test_fitness:.2f}")
# Out:
# Best Score:  58250.12867411893
# Best Parameters:
# Short SMA weight: 0.231057
# Short SMA length: 60
# Short LMA weight: 0.765367
# Short LMA length: 70
# Short EMA weight: 0.924194
# Short EMA length: 77
# Short EMA alpha: 0.934025
# Long SMA weight: 0.131145
# Long SMA length: 233
# Long LMA weight: 0.644182
# Long LMA length: 179
# Long EMA weight: 0.0
# Long EMA length: 289
# Long EMA alpha: 0.444717
# Test set fitness: 767.54

# %%
#HCA Invoke

# Import data
data = import_data(DATA_PATH)
training_data, testing_data = training_testing_split(data, datetime(2020, 1, 1).timestamp())

# Define parameter bounds
bounds = [
    (0, 1), (1, 100), (0, 1),  # SMA parameters
    (1, 100), (0, 1), (1, 100),  # LMA parameters
    (0, 1), (0, 1), (1, 100),  # EMA parameters
    (0, 1), (1, 100), (0, 1),  # SMA parameters
    (1, 100), (0, 1), (1, 100),  # LMA parameters
    (0, 1)  # EMA parameters
]


# Create objective function
def objective_function(params):
    return evaluate(params, training_data[1])


# Create HCA optimizer
hca = HCA(
    objective_func=objective_function,
    bounds=bounds,
    step_size=0.1,
    n_iterations=1000
)

# Execute optimization
best_params, best_fitness = hca.optimize()

print("\nOptimization Results:")
print(f"Best parameters: {best_params}")
print(f"Best fitness: {best_fitness:.2f}")

# Evaluate best parameters on test set
test_fitness = evaluate(best_params, testing_data[1], plot=True)
print(f"Test set fitness: {test_fitness:.2f}")
# Out:
# Iteration 1/1000, Current fitness: 9434.68, Best fitness: 9434.68
# Iteration 2/1000, Current fitness: 9434.68, Best fitness: 9434.68
# Iteration 3/1000, Current fitness: 9434.68, Best fitness: 9434.68
# Iteration 4/1000, Current fitness: 9445.99, Best fitness: 9445.99
# Iteration 5/1000, Current fitness: 9445.99, Best fitness: 9445.99
# Iteration 6/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 7/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 8/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 9/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 10/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 11/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 12/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 13/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 14/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 15/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 16/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 17/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 18/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 19/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 20/1000, Current fitness: 10275.65, Best fitness: 10275.65
# Iteration 21/1000, Current fitness: 10482.57, Best fitness: 10482.57
# Iteration 22/1000, Current fitness: 10482.57, Best fitness: 10482.57
# Iteration 23/1000, Current fitness: 10482.57, Best fitness: 10482.57
# Iteration 24/1000, Current fitness: 10482.57, Best fitness: 10482.57
# Iteration 25/1000, Current fitness: 10482.57, Best fitness: 10482.57
# Iteration 26/1000, Current fitness: 10482.57, Best fitness: 10482.57
# Iteration 27/1000, Current fitness: 10482.57, Best fitness: 10482.57
# Iteration 28/1000, Current fitness: 10482.57, Best fitness: 10482.57
# Iteration 29/1000, Current fitness: 10482.57, Best fitness: 10482.57
# Iteration 30/1000, Current fitness: 10482.57, Best fitness: 10482.57
# Iteration 31/1000, Current fitness: 10649.14, Best fitness: 10649.14
# Iteration 32/1000, Current fitness: 10649.14, Best fitness: 10649.14
# Iteration 33/1000, Current fitness: 10649.14, Best fitness: 10649.14
# Iteration 34/1000, Current fitness: 10649.14, Best fitness: 10649.14
# Iteration 35/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 36/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 37/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 38/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 39/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 40/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 41/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 42/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 43/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 44/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 45/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 46/1000, Current fitness: 11059.69, Best fitness: 11059.69
# Iteration 47/1000, Current fitness: 11908.00, Best fitness: 11908.00
# Iteration 48/1000, Current fitness: 11908.00, Best fitness: 11908.00
# Iteration 49/1000, Current fitness: 11908.00, Best fitness: 11908.00
# Iteration 50/1000, Current fitness: 11908.00, Best fitness: 11908.00
# Iteration 51/1000, Current fitness: 11908.00, Best fitness: 11908.00
# Iteration 52/1000, Current fitness: 11908.00, Best fitness: 11908.00
# Iteration 53/1000, Current fitness: 11908.00, Best fitness: 11908.00
# Iteration 54/1000, Current fitness: 11908.00, Best fitness: 11908.00
# Iteration 55/1000, Current fitness: 11908.00, Best fitness: 11908.00
# Iteration 56/1000, Current fitness: 12584.90, Best fitness: 12584.90
# Iteration 57/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 58/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 59/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 60/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 61/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 62/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 63/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 64/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 65/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 66/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 67/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 68/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 69/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 70/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 71/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 72/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 73/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 74/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 75/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 76/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 77/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 78/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 79/1000, Current fitness: 12609.43, Best fitness: 12609.43
# Iteration 80/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 81/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 82/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 83/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 84/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 85/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 86/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 87/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 88/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 89/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 90/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 91/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 92/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 93/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 94/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 95/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 96/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 97/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 98/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 99/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 100/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 101/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 102/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 103/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 104/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 105/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 106/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 107/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 108/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 109/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 110/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 111/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 112/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 113/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 114/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 115/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 116/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 117/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 118/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 119/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 120/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 121/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 122/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 123/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 124/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 125/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 126/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 127/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 128/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 129/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 130/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 131/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 132/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 133/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 134/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 135/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 136/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 137/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 138/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 139/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 140/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 141/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 142/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 143/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 144/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 145/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 146/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 147/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 148/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 149/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 150/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 151/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 152/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 153/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 154/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 155/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 156/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 157/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 158/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 159/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 160/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 161/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 162/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 163/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 164/1000, Current fitness: 12763.51, Best fitness: 12763.51
# Iteration 165/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 166/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 167/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 168/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 169/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 170/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 171/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 172/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 173/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 174/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 175/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 176/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 177/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 178/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 179/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 180/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 181/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 182/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 183/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 184/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 185/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 186/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 187/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 188/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 189/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 190/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 191/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 192/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 193/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 194/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 195/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 196/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 197/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 198/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 199/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 200/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 201/1000, Current fitness: 12773.71, Best fitness: 12773.71
# Iteration 202/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 203/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 204/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 205/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 206/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 207/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 208/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 209/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 210/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 211/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 212/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 213/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 214/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 215/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 216/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 217/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 218/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 219/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 220/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 221/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 222/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 223/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 224/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 225/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 226/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 227/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 228/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 229/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 230/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 231/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 232/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 233/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 234/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 235/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 236/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 237/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 238/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 239/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 240/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 241/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 242/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 243/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 244/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 245/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 246/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 247/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 248/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 249/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 250/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 251/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 252/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 253/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 254/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 255/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 256/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 257/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 258/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 259/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 260/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 261/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 262/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 263/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 264/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 265/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 266/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 267/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 268/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 269/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 270/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 271/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 272/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 273/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 274/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 275/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 276/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 277/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 278/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 279/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 280/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 281/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 282/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 283/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 284/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 285/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 286/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 287/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 288/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 289/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 290/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 291/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 292/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 293/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 294/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 295/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 296/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 297/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 298/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 299/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 300/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 301/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 302/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 303/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 304/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 305/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 306/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 307/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 308/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 309/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 310/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 311/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 312/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 313/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 314/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 315/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 316/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 317/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 318/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 319/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 320/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 321/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 322/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 323/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 324/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 325/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 326/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 327/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 328/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 329/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 330/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 331/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 332/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 333/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 334/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 335/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 336/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 337/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 338/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 339/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 340/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 341/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 342/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 343/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 344/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 345/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 346/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 347/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 348/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 349/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 350/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 351/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 352/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 353/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 354/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 355/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 356/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 357/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 358/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 359/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 360/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 361/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 362/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 363/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 364/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 365/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 366/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 367/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 368/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 369/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 370/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 371/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 372/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 373/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 374/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 375/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 376/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 377/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 378/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 379/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 380/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 381/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 382/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 383/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 384/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 385/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 386/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 387/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 388/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 389/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 390/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 391/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 392/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 393/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 394/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 395/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 396/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 397/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 398/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 399/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 400/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 401/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 402/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 403/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 404/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 405/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 406/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 407/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 408/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 409/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 410/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 411/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 412/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 413/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 414/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 415/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 416/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 417/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 418/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 419/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 420/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 421/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 422/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 423/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 424/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 425/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 426/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 427/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 428/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 429/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 430/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 431/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 432/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 433/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 434/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 435/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 436/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 437/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 438/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 439/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 440/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 441/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 442/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 443/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 444/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 445/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 446/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 447/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 448/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 449/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 450/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 451/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 452/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 453/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 454/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 455/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 456/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 457/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 458/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 459/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 460/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 461/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 462/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 463/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 464/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 465/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 466/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 467/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 468/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 469/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 470/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 471/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 472/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 473/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 474/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 475/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 476/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 477/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 478/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 479/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 480/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 481/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 482/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 483/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 484/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 485/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 486/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 487/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 488/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 489/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 490/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 491/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 492/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 493/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 494/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 495/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 496/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 497/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 498/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 499/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 500/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 501/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 502/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 503/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 504/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 505/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 506/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 507/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 508/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 509/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 510/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 511/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 512/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 513/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 514/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 515/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 516/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 517/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 518/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 519/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 520/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 521/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 522/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 523/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 524/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 525/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 526/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 527/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 528/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 529/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 530/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 531/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 532/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 533/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 534/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 535/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 536/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 537/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 538/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 539/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 540/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 541/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 542/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 543/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 544/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 545/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 546/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 547/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 548/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 549/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 550/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 551/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 552/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 553/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 554/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 555/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 556/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 557/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 558/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 559/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 560/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 561/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 562/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 563/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 564/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 565/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 566/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 567/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 568/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 569/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 570/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 571/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 572/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 573/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 574/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 575/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 576/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 577/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 578/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 579/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 580/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 581/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 582/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 583/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 584/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 585/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 586/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 587/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 588/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 589/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 590/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 591/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 592/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 593/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 594/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 595/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 596/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 597/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 598/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 599/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 600/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 601/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 602/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 603/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 604/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 605/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 606/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 607/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 608/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 609/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 610/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 611/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 612/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 613/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 614/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 615/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 616/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 617/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 618/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 619/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 620/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 621/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 622/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 623/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 624/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 625/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 626/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 627/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 628/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 629/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 630/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 631/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 632/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 633/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 634/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 635/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 636/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 637/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 638/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 639/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 640/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 641/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 642/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 643/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 644/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 645/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 646/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 647/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 648/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 649/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 650/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 651/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 652/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 653/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 654/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 655/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 656/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 657/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 658/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 659/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 660/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 661/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 662/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 663/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 664/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 665/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 666/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 667/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 668/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 669/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 670/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 671/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 672/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 673/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 674/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 675/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 676/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 677/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 678/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 679/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 680/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 681/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 682/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 683/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 684/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 685/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 686/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 687/1000, Current fitness: 12972.71, Best fitness: 12972.71
# ...
# Iteration 777/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 778/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 779/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 780/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 781/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 782/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 783/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 784/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 785/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 786/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 787/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 788/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 789/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 790/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 791/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 792/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 793/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 794/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 795/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 796/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 797/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 798/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 799/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 800/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 801/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 802/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 803/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 804/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 805/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 806/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 807/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 808/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 809/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 810/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 811/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 812/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 813/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 814/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 815/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 816/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 817/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 818/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 819/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 820/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 821/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 822/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 823/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 824/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 825/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 826/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 827/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 828/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 829/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 830/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 831/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 832/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 833/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 834/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 835/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 836/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 837/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 838/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 839/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 840/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 841/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 842/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 843/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 844/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 845/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 846/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 847/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 848/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 849/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 850/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 851/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 852/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 853/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 854/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 855/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 856/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 857/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 858/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 859/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 860/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 861/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 862/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 863/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 864/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 865/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 866/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 867/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 868/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 869/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 870/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 871/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 872/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 873/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 874/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 875/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 876/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 877/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 878/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 879/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 880/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 881/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 882/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 883/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 884/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 885/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 886/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 887/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 888/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 889/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 890/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 891/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 892/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 893/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 894/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 895/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 896/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 897/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 898/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 899/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 900/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 901/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 902/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 903/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 904/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 905/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 906/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 907/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 908/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 909/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 910/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 911/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 912/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 913/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 914/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 915/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 916/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 917/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 918/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 919/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 920/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 921/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 922/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 923/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 924/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 925/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 926/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 927/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 928/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 929/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 930/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 931/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 932/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 933/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 934/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 935/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 936/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 937/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 938/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 939/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 940/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 941/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 942/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 943/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 944/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 945/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 946/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 947/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 948/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 949/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 950/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 951/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 952/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 953/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 954/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 955/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 956/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 957/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 958/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 959/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 960/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 961/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 962/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 963/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 964/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 965/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 966/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 967/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 968/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 969/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 970/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 971/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 972/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 973/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 974/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 975/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 976/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 977/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 978/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 979/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 980/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 981/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 982/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 983/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 984/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 985/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 986/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 987/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 988/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 989/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 990/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 991/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 992/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 993/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 994/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 995/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 996/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 997/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 998/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 999/1000, Current fitness: 12972.71, Best fitness: 12972.71
# Iteration 1000/1000, Current fitness: 12972.71, Best fitness: 12972.71
#
# Optimization Results:
# Best parameters: [ 0.1601134  59.          0.76191734 22.          0.42979743 80.
#   0.39118512  0.91177431  7.          0.86668336 99.          0.34679103
#  55.          0.673855    8.30097857  0.52639   ]
# Best fitness: 12972.71
# Test set fitness: 1773.45

# %%
# ABC Implementation
class ABC:
    def __init__(self, objective_func, bounds, n_bees=50, n_iterations=100, limit=50):
        """
        Artificial Bee Colony Algorithm implementation

        Parameters:
        - objective_func: Objective function to optimize
        - bounds: Parameter bounds [(min, max), ...]
        - n_bees: Number of bees
        - n_iterations: Number of iterations
        - limit: Maximum number of trials
        """
        self.objective_func = objective_func
        self.bounds = bounds
        self.n_bees = n_bees
        self.n_iterations = n_iterations
        self.limit = limit
        self.dim = len(bounds)

        # Initialize bee positions
        self.positions = np.random.uniform(
            [b[0] for b in bounds],
            [b[1] for b in bounds],
            (n_bees, self.dim)
        )

        # Initialize fitness
        self.fitness = np.zeros(n_bees)
        self.trials = np.zeros(n_bees)
        self.best_solution = None
        self.best_fitness = float('-inf')

    def evaluate_fitness(self, position):
        """Evaluate fitness of a position"""
        return self.objective_func(position)

    def employed_bee_phase(self):
        """Employed bee phase"""
        for i in range(self.n_bees):
            # Randomly select a dimension
            j = np.random.randint(self.dim)
            # Randomly select a different bee
            k = np.random.randint(self.n_bees)
            while k == i:
                k = np.random.randint(self.n_bees)

            # Generate new solution
            new_position = self.positions[i].copy()
            phi = np.random.uniform(-1, 1)
            new_position[j] = self.positions[i][j] + phi * (self.positions[i][j] - self.positions[k][j])

            # Ensure new solution is within bounds
            new_position[j] = np.clip(new_position[j], self.bounds[j][0], self.bounds[j][1])

            # Evaluate new solution
            new_fitness = self.evaluate_fitness(new_position)

            # Update if new solution is better
            if new_fitness > self.fitness[i]:
                self.positions[i] = new_position
                self.fitness[i] = new_fitness
                self.trials[i] = 0
            else:
                self.trials[i] += 1

    def onlooker_bee_phase(self):
        """Onlooker bee phase"""
        # Calculate selection probabilities
        fitness_sum = np.sum(self.fitness)
        if fitness_sum == 0:
            probabilities = np.ones(self.n_bees) / self.n_bees
        else:
            probabilities = self.fitness / fitness_sum

        for _ in range(self.n_bees):
            # Roulette wheel selection
            i = np.random.choice(self.n_bees, p=probabilities)

            # Randomly select a dimension
            j = np.random.randint(self.dim)
            # Randomly select a different bee
            k = np.random.randint(self.n_bees)
            while k == i:
                k = np.random.randint(self.n_bees)

            # Generate new solution
            new_position = self.positions[i].copy()
            phi = np.random.uniform(-1, 1)
            new_position[j] = self.positions[i][j] + phi * (self.positions[i][j] - self.positions[k][j])

            # Ensure new solution is within bounds
            new_position[j] = np.clip(new_position[j], self.bounds[j][0], self.bounds[j][1])

            # Evaluate new solution
            new_fitness = self.evaluate_fitness(new_position)

            # Update if new solution is better
            if new_fitness > self.fitness[i]:
                self.positions[i] = new_position
                self.fitness[i] = new_fitness
                self.trials[i] = 0
            else:
                self.trials[i] += 1

    def scout_bee_phase(self):
        """Scout bee phase"""
        for i in range(self.n_bees):
            if self.trials[i] >= self.limit:
                # Reinitialize the position of this bee
                self.positions[i] = np.random.uniform(
                    [b[0] for b in self.bounds],
                    [b[1] for b in self.bounds],
                    self.dim
                )
                self.fitness[i] = self.evaluate_fitness(self.positions[i])
                self.trials[i] = 0

    def optimize(self):
        """Execute optimization"""
        # Initialize fitness
        for i in range(self.n_bees):
            self.fitness[i] = self.evaluate_fitness(self.positions[i])

        # Record best solution
        best_idx = np.argmax(self.fitness)
        self.best_solution = self.positions[best_idx].copy()
        self.best_fitness = self.fitness[best_idx]

        # Iterative optimization
        for iteration in range(self.n_iterations):
            self.employed_bee_phase()
            self.onlooker_bee_phase()
            self.scout_bee_phase()

            # Update best solution
            current_best_idx = np.argmax(self.fitness)
            if self.fitness[current_best_idx] > self.best_fitness:
                self.best_solution = self.positions[current_best_idx].copy()
                self.best_fitness = self.fitness[current_best_idx]

            print(f"Iteration {iteration + 1}/{self.n_iterations}, Best fitness: {self.best_fitness:.2f}")

        return self.best_solution, self.best_fitness

# %%
# ABC Invoke

# Main program
# Import data
data = import_data(DATA_PATH)
training_data, testing_data = training_testing_split(data, datetime(2020, 1, 1).timestamp())

# Define parameter bounds
bounds = [
    (0, 1), (1, 100), (0, 1),  # SMA parameters
    (1, 100), (0, 1), (1, 100),  # LMA parameters
    (0, 1), (0, 1), (1, 100),  # EMA parameters
    (0, 1), (1, 100), (0, 1),  # SMA parameters
    (1, 100), (0, 1), (1, 100),  # LMA parameters
    (0, 1)  # EMA parameters
]


# Create objective function
def objective_function(params):
    return evaluate(params, training_data[1])


# Create ABC optimizer
abc = ABC(
    objective_func=objective_function,
    bounds=bounds,
    n_bees=50,
    n_iterations=100,
    limit=50
)

# Execute optimization
best_params, best_fitness = abc.optimize()

print("\nOptimization Results:")
print(f"Best parameters: {best_params}")
print(f"Best fitness: {best_fitness:.2f}")

# Evaluate best parameters on test set
test_fitness = evaluate(best_params, testing_data[1], plot=True)
print(f"Test set fitness: {test_fitness:.2f}")
# Out:
# Iteration 1/100, Best fitness: 18065.86
# Iteration 2/100, Best fitness: 29390.58
# Iteration 3/100, Best fitness: 30149.61
# Iteration 4/100, Best fitness: 33706.70
# Iteration 5/100, Best fitness: 33706.70
# Iteration 6/100, Best fitness: 33706.70
# Iteration 7/100, Best fitness: 33706.70
# Iteration 8/100, Best fitness: 33706.70
# Iteration 9/100, Best fitness: 33706.70
# Iteration 10/100, Best fitness: 34233.98
# Iteration 11/100, Best fitness: 34233.98
# Iteration 12/100, Best fitness: 34630.85
# Iteration 13/100, Best fitness: 34630.85
# Iteration 14/100, Best fitness: 34630.85
# Iteration 15/100, Best fitness: 34630.85
# Iteration 16/100, Best fitness: 41634.01
# Iteration 17/100, Best fitness: 41634.01
# Iteration 18/100, Best fitness: 41694.79
# Iteration 19/100, Best fitness: 44779.80
# Iteration 20/100, Best fitness: 44779.80
# Iteration 21/100, Best fitness: 49619.42
# Iteration 22/100, Best fitness: 49619.42
# Iteration 23/100, Best fitness: 49901.42
# Iteration 24/100, Best fitness: 49901.42
# Iteration 25/100, Best fitness: 52116.72
# Iteration 26/100, Best fitness: 52116.72
# Iteration 27/100, Best fitness: 53091.31
# Iteration 28/100, Best fitness: 53091.31
# Iteration 29/100, Best fitness: 53091.31
# Iteration 30/100, Best fitness: 53091.31
# Iteration 31/100, Best fitness: 53091.31
# Iteration 32/100, Best fitness: 53091.31
# Iteration 33/100, Best fitness: 53091.31
# Iteration 34/100, Best fitness: 53091.31
# Iteration 35/100, Best fitness: 53091.31
# Iteration 36/100, Best fitness: 53091.31
# Iteration 37/100, Best fitness: 53091.31
# Iteration 38/100, Best fitness: 53091.31
# Iteration 39/100, Best fitness: 53091.31
# Iteration 40/100, Best fitness: 53091.31
# Iteration 41/100, Best fitness: 53091.31
# Iteration 42/100, Best fitness: 53091.31
# Iteration 43/100, Best fitness: 53091.31
# Iteration 44/100, Best fitness: 53091.31
# Iteration 45/100, Best fitness: 53091.31
# Iteration 46/100, Best fitness: 53091.31
# Iteration 47/100, Best fitness: 53091.31
# Iteration 48/100, Best fitness: 53091.31
# Iteration 49/100, Best fitness: 53091.31
# Iteration 50/100, Best fitness: 53091.31
# Iteration 51/100, Best fitness: 53091.31
# Iteration 52/100, Best fitness: 53091.31
# Iteration 53/100, Best fitness: 53091.31
# Iteration 54/100, Best fitness: 53091.31
# Iteration 55/100, Best fitness: 53091.31
# Iteration 56/100, Best fitness: 53455.86
# Iteration 57/100, Best fitness: 53455.86
# Iteration 58/100, Best fitness: 53455.86
# Iteration 59/100, Best fitness: 53455.86
# Iteration 60/100, Best fitness: 53455.86
# Iteration 61/100, Best fitness: 53455.86
# Iteration 62/100, Best fitness: 53455.86
# Iteration 63/100, Best fitness: 53455.86
# Iteration 64/100, Best fitness: 53455.86
# Iteration 65/100, Best fitness: 53455.86
# Iteration 66/100, Best fitness: 53455.86
# Iteration 67/100, Best fitness: 53455.86
# Iteration 68/100, Best fitness: 53455.86
# Iteration 69/100, Best fitness: 53455.86
# Iteration 70/100, Best fitness: 53455.86
# Iteration 71/100, Best fitness: 53455.86
# Iteration 72/100, Best fitness: 53455.86
# Iteration 73/100, Best fitness: 53455.86
# Iteration 74/100, Best fitness: 53455.86
# Iteration 75/100, Best fitness: 53455.86
# Iteration 76/100, Best fitness: 53455.86
# Iteration 77/100, Best fitness: 53455.86
# Iteration 78/100, Best fitness: 53455.86
# Iteration 79/100, Best fitness: 53455.86
# Iteration 80/100, Best fitness: 53455.86
# Iteration 81/100, Best fitness: 53455.86
# Iteration 82/100, Best fitness: 53455.86
# Iteration 83/100, Best fitness: 53455.86
# Iteration 84/100, Best fitness: 53455.86
# Iteration 85/100, Best fitness: 53455.86
# Iteration 86/100, Best fitness: 53455.86
# Iteration 87/100, Best fitness: 53455.86
# Iteration 88/100, Best fitness: 53455.86
# Iteration 89/100, Best fitness: 53455.86
# Iteration 90/100, Best fitness: 53455.86
# Iteration 91/100, Best fitness: 53455.86
# Iteration 92/100, Best fitness: 53455.86
# Iteration 93/100, Best fitness: 53455.86
# Iteration 94/100, Best fitness: 53455.86
# Iteration 95/100, Best fitness: 53455.86
# Iteration 96/100, Best fitness: 53455.86
# Iteration 97/100, Best fitness: 53455.86
# Iteration 98/100, Best fitness: 53455.86
# Iteration 99/100, Best fitness: 53455.86
# Iteration 100/100, Best fitness: 53455.86
#
# Optimization Results:
# Best parameters: [ 0.33622298 64.          0.58497049 57.          0.2931298  53.
#   0.42887478  0.54243716 23.          0.66088858 20.          0.2250859
#  98.          0.         47.07591217  0.14686272]
# Best fitness: 53455.86
# Test set fitness: 4227.01
